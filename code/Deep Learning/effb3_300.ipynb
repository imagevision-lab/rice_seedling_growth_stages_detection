# %%
# Importing the appropriate libraries
import keras.backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import numpy as np
import itertools
import os
import keras

# %%
# Initial settings
im_height = 300
im_width = 300
batch_size = 16
epochs = 50
num_classes = 3
labels = ['1','2','3']
save_path = './save_weights/effb3_300-{epoch:02d}-{val_accuracy:.2f}.h5'
save_json = './csv/effb3_300.csv'

image_path = 'G:/dataset/seedling_classification_300/'
train_dir = image_path + "train"
val_dir = image_path + "val"
test_dir = image_path + "test"

# %%
# Data pre-processing
train_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
#     horizontal_flip=True,
#     vertical_flip=True,
)
val_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)
test_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
# Generate dataset
train_data_gen = train_image_generator.flow_from_directory(directory=train_dir,
                                                           batch_size=batch_size,
                                                           shuffle=True,
                                                           color_mode="rgb",
                                                           target_size=(im_height, im_width),
                                                           class_mode='categorical')
total_train = train_data_gen.n

val_data_gen = val_image_generator.flow_from_directory( directory=val_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                       color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_val = val_data_gen.n

test_data_gen = test_image_generator.flow_from_directory( directory=test_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                         color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_test = test_data_gen.n
# Out:
# Found 10896 images belonging to 3 classes.
# Found 3633 images belonging to 3 classes.
# Found 3634 images belonging to 3 classes.

# %%
# Building the model
covn_base = tf.keras.applications.EfficientNetB3(weights='imagenet', include_top = False,
                                              input_shape=(im_height,im_width,3))
covn_base.trainable = False
model = tf.keras.Sequential([
        covn_base,
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(units = 32, activation = 'relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(num_classes, activation='softmax',
                              kernel_regularizer='l2'
                             )
    ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb3 (Functional)  (None, 10, 10, 1536)      10783535
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10, 10, 1536)      6144
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 10, 1536)      0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                49184
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 10,838,962
# Trainable params: 52,355
# Non-trainable params: 10,786,607
# _________________________________________________________________

# %%
# Building the model
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Monitor the change of 'val_loss', if the learning rate decays to 1/5 of the original one after four rounds of constant learning
reduce_lr = ReduceLROnPlateau(
                                monitor='val_loss', 
                                factor=0.2, 
                                patience=4, 
                                mode='auto',
                                verbose=VERBOSE
                             )

# Set the model save path and save the optimal model according to val_acc
checkpoint = ModelCheckpoint(
                                filepath=save_path,
                                monitor='val_accuracy', 
                                save_weights_only=True, 
                                save_best_only=True, 
                                mode='auto'
                            )
# Start training
history = model.fit(x=train_data_gen,
                    epochs=epochs,
                    validation_data=val_data_gen,
                    verbose=VERBOSE,
                    callbacks=[checkpoint, reduce_lr])
# Out:
# Epoch 1/50
# 681/681 [==============================] - 63s 93ms/step - loss: 0.3301 - accuracy: 0.8897 - val_loss: 0.2152 - val_accuracy: 0.9323
# Epoch 2/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.2403 - accuracy: 0.9212 - val_loss: 0.1447 - val_accuracy: 0.9549
# Epoch 3/50
# 681/681 [==============================] - 61s 90ms/step - loss: 0.2158 - accuracy: 0.9271 - val_loss: 0.1248 - val_accuracy: 0.9595
# Epoch 4/50
# 681/681 [==============================] - 61s 89ms/step - loss: 0.1909 - accuracy: 0.9365 - val_loss: 0.1156 - val_accuracy: 0.9620
# Epoch 5/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.1757 - accuracy: 0.9397 - val_loss: 0.1031 - val_accuracy: 0.9681
# Epoch 6/50
# 681/681 [==============================] - 61s 89ms/step - loss: 0.1688 - accuracy: 0.9439 - val_loss: 0.0994 - val_accuracy: 0.9689
# Epoch 7/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1704 - accuracy: 0.9419 - val_loss: 0.1033 - val_accuracy: 0.9664
# Epoch 8/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1639 - accuracy: 0.9437 - val_loss: 0.0919 - val_accuracy: 0.9722
# Epoch 9/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.1585 - accuracy: 0.9452 - val_loss: 0.0916 - val_accuracy: 0.9733
# Epoch 10/50
# 681/681 [==============================] - 59s 87ms/step - loss: 0.1474 - accuracy: 0.9498 - val_loss: 0.0928 - val_accuracy: 0.9686
# Epoch 11/50
# 681/681 [==============================] - 62s 91ms/step - loss: 0.1437 - accuracy: 0.9505 - val_loss: 0.0870 - val_accuracy: 0.9714
# Epoch 12/50
# 681/681 [==============================] - 61s 90ms/step - loss: 0.1404 - accuracy: 0.9526 - val_loss: 0.0883 - val_accuracy: 0.9694
# Epoch 13/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1375 - accuracy: 0.9527 - val_loss: 0.0778 - val_accuracy: 0.9747
# Epoch 14/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1457 - accuracy: 0.9459 - val_loss: 0.0888 - val_accuracy: 0.9719
# Epoch 15/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1342 - accuracy: 0.9533 - val_loss: 0.0806 - val_accuracy: 0.9747
# Epoch 16/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.1345 - accuracy: 0.9556 - val_loss: 0.0884 - val_accuracy: 0.9675
# Epoch 17/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1379 - accuracy: 0.9510 - val_loss: 0.0713 - val_accuracy: 0.9788
# Epoch 18/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1302 - accuracy: 0.9546 - val_loss: 0.0894 - val_accuracy: 0.9700
# Epoch 19/50
# 681/681 [==============================] - 59s 87ms/step - loss: 0.1308 - accuracy: 0.9522 - val_loss: 0.0726 - val_accuracy: 0.9772
# Epoch 20/50
# 681/681 [==============================] - 61s 90ms/step - loss: 0.1306 - accuracy: 0.9542 - val_loss: 0.0723 - val_accuracy: 0.9780
# Epoch 21/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1285 - accuracy: 0.9564 - val_loss: 0.0686 - val_accuracy: 0.9777
# Epoch 22/50
# 681/681 [==============================] - 61s 89ms/step - loss: 0.1317 - accuracy: 0.9524 - val_loss: 0.0771 - val_accuracy: 0.9752
# Epoch 23/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1208 - accuracy: 0.9597 - val_loss: 0.0656 - val_accuracy: 0.9791
# Epoch 24/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1254 - accuracy: 0.9565 - val_loss: 0.0743 - val_accuracy: 0.9777
# Epoch 25/50
# 681/681 [==============================] - 61s 89ms/step - loss: 0.1192 - accuracy: 0.9604 - val_loss: 0.0645 - val_accuracy: 0.9807
# Epoch 26/50
# 681/681 [==============================] - 62s 91ms/step - loss: 0.1234 - accuracy: 0.9571 - val_loss: 0.0791 - val_accuracy: 0.9744
# Epoch 27/50
# 681/681 [==============================] - 59s 87ms/step - loss: 0.1222 - accuracy: 0.9564 - val_loss: 0.0694 - val_accuracy: 0.9763
# Epoch 28/50
# 681/681 [==============================] - 61s 89ms/step - loss: 0.1161 - accuracy: 0.9594 - val_loss: 0.0724 - val_accuracy: 0.9755
# Epoch 29/50
# 681/681 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9604
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1153 - accuracy: 0.9604 - val_loss: 0.0715 - val_accuracy: 0.9761
# Epoch 30/50
# 681/681 [==============================] - 59s 87ms/step - loss: 0.1067 - accuracy: 0.9640 - val_loss: 0.0646 - val_accuracy: 0.9785
# Epoch 31/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1114 - accuracy: 0.9618 - val_loss: 0.0684 - val_accuracy: 0.9780
# Epoch 32/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1076 - accuracy: 0.9620 - val_loss: 0.0604 - val_accuracy: 0.9813
# Epoch 33/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.1135 - accuracy: 0.9612 - val_loss: 0.0646 - val_accuracy: 0.9791
# Epoch 34/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1083 - accuracy: 0.9640 - val_loss: 0.0621 - val_accuracy: 0.9799
# Epoch 35/50
# 681/681 [==============================] - 61s 89ms/step - loss: 0.1019 - accuracy: 0.9651 - val_loss: 0.0589 - val_accuracy: 0.9807
# Epoch 36/50
# 681/681 [==============================] - 61s 90ms/step - loss: 0.1001 - accuracy: 0.9676 - val_loss: 0.0595 - val_accuracy: 0.9813
# Epoch 37/50
# 681/681 [==============================] - 60s 87ms/step - loss: 0.1061 - accuracy: 0.9647 - val_loss: 0.0625 - val_accuracy: 0.9799
# Epoch 38/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.0995 - accuracy: 0.9675 - val_loss: 0.0626 - val_accuracy: 0.9794
# Epoch 39/50
# 681/681 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9670
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 681/681 [==============================] - 60s 88ms/step - loss: 0.0990 - accuracy: 0.9670 - val_loss: 0.0590 - val_accuracy: 0.9821
# Epoch 40/50
# 681/681 [==============================] - 59s 87ms/step - loss: 0.0990 - accuracy: 0.9657 - val_loss: 0.0604 - val_accuracy: 0.9802
# Epoch 41/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1000 - accuracy: 0.9664 - val_loss: 0.0606 - val_accuracy: 0.9799
# Epoch 42/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.0929 - accuracy: 0.9697 - val_loss: 0.0596 - val_accuracy: 0.9802
# Epoch 43/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1025 - accuracy: 0.9649 - val_loss: 0.0587 - val_accuracy: 0.9821
# Epoch 44/50
# 681/681 [==============================] - 60s 89ms/step - loss: 0.0981 - accuracy: 0.9671 - val_loss: 0.0609 - val_accuracy: 0.9799
# Epoch 45/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1004 - accuracy: 0.9656 - val_loss: 0.0588 - val_accuracy: 0.9816
# Epoch 46/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1034 - accuracy: 0.9654 - val_loss: 0.0587 - val_accuracy: 0.9810
# Epoch 47/50
# 681/681 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9676
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 681/681 [==============================] - 60s 88ms/step - loss: 0.1011 - accuracy: 0.9676 - val_loss: 0.0604 - val_accuracy: 0.9799
# Epoch 48/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.0975 - accuracy: 0.9684 - val_loss: 0.0613 - val_accuracy: 0.9799
# Epoch 49/50
# 681/681 [==============================] - 60s 88ms/step - loss: 0.0992 - accuracy: 0.9661 - val_loss: 0.0611 - val_accuracy: 0.9796
# Epoch 50/50
# 681/681 [==============================] - 61s 89ms/step - loss: 0.1055 - accuracy: 0.9644 - val_loss: 0.0613 - val_accuracy: 0.9796

# %%
# Plotting model accuracy and loss variation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Load the best model in training
try:
    model.load_weights("./save_weights/300/effb3/effb3_300-39-0.98.h5")
    print("Loading model successfully")
except :    
    print("Failed to load model")
# Out:
# Loading model successfully

# %%
test_loss, test_acc = model.evaluate(val_data_gen)

print('\nTest accuracy:', test_acc)
print('\nTest loss:', test_loss)
# Out:
# 228/228 [==============================] - 14s 63ms/step - loss: 0.0590 - accuracy: 0.9821
#
# Test accuracy: 0.982108473777771
#
# Test loss: 0.05898626148700714

# %%
test_loss, test_acc = model.evaluate(test_data_gen)

print('\nTest accuracy:', test_acc)
print('\nTest loss:', test_loss)
# Out:
# 228/228 [==============================] - 15s 64ms/step - loss: 0.0551 - accuracy: 0.9843
#
# Test accuracy: 0.9843147993087769
#
# Test loss: 0.055055126547813416

# %%
def plot_confusion_matrix(cm):
    print(cm)
    accuracy = np.trace(cm) / float(np.sum(cm))
    precision = (cm[0][0]/cm.sum(axis=0)[0] + cm[1][1]/cm.sum(axis=0)[1] + cm[2][2]/cm.sum(axis=0)[2])/3
    recall = (cm[0][0]/cm.sum(axis=1)[0] + cm[1][1]/cm.sum(axis=1)[1] + cm[2][2]/cm.sum(axis=1)[2])/3
    f1 = 2*precision*recall/(precision + recall)
    print('accuracy',accuracy)
    print('precision',precision)
    print('recall',recall)
    print('f1',f1)

# %%
# Predict the overall accuracy of the validation set data
Y_pred = model.predict(val_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = val_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[1076    3    0]
#  [   9 1339   39]
#  [   1   13 1153]]
# accuracy 0.9821084503165428
# precision 0.9820885526608983
# recall 0.9835386699349818
# f1 0.9828130763948607

# %%
# Predict the overall accuracy of the test set data
Y_pred = model.predict(test_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = test_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[1079    0    0]
#  [  11 1342   35]
#  [   0   11 1156]]
# accuracy 0.9843148046230049
# precision 0.9841303686301948
# recall 0.9858109704349601
# f1 0.9849699526527469

# %%
# Record the predicted classification and predicted probability in the table
# import csv
# from keras.utils import to_categorical

# Y_test = to_categorical(test_data_gen.labels)
# Y_tes = Y_test.ravel()
# Y_pre = Y_pred.ravel()
# num = len(Y_tes)

# with open(save_json,'w',newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     for i in range(num):
#         writer.writerow([Y_tes[i], Y_pre[i]])

# %%
# Statistical prediction of misclassified images
import csv

misclass = []
# Save as csv file
with open('pred.csv', 'w', newline="") as csvfile:
    fieldnames = ['i', 'file_name', 'pred_label', 'ground_label']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)    
    writer.writeheader()
    num = len(test_data_gen.filenames)

    for i in range(num):
        file_name = test_data_gen.filenames[i]
        pred = Y_pred_classes[i]+1
        ground = int(file_name[:1])
        if pred != ground:
            str = {'i': i, 
                   'file_name': file_name, 
                   'pred_label': pred, 
                   'ground_label': ground}
            writer.writerow(str)
            line=[i,file_name,pred,ground,Y_pred[i]]
            misclass.append(line)
# print(misclass)

# %%
fig = plt.figure(figsize=(26,26))
a=1
img_scale = (600, 600)
num = min(len(misclass),12)

for i in range(num):
    img = Image.open(os.path.join(image_path, 'test' , misclass[i][1]))
    img = img.resize(img_scale)
    img = img.convert("RGB")
    plt.subplot(4,3,a)
    plt.axis('off')
    a+=1
    
    plt.title(['pre:',misclass[i][2],  # Prediction classification
               'gt:', misclass[i][3],  # Actual classification
               'pro:', ''.join( '%.5s ' %a for a in misclass[i][4] )], fontsize=20) # Probability
    plt.imshow(img)
plt.show()
