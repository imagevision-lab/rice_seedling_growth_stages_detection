# %%
# Importing the appropriate libraries
import keras.backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import numpy as np
import itertools
import os
import keras

# %%
# Initial settings
im_height = 224 
im_width = 224
batch_size = 32
epochs = 50
num_classes = 3
labels = ['1','2','3']
save_path = './save_weights/des121_224-{epoch:02d}-{val_accuracy:.2f}.h5'
save_json = './csv/des121_224.csv'

image_path = 'G:/dataset/seedling_classification_224/'
VERBOSE = 1
train_dir = image_path + "train"
val_dir = image_path + "val"
test_dir = image_path + "test"

# %%
# Data pre-processing
train_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.densenet.preprocess_input,
#     horizontal_flip=True,
#     vertical_flip=True,
)
val_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.densenet.preprocess_input,
)
test_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.densenet.preprocess_input,
)

# %%
# Generate dataset
train_data_gen = train_image_generator.flow_from_directory(directory=train_dir,
                                                           batch_size=batch_size,
                                                           shuffle=True,
                                                           color_mode="rgb",
                                                           target_size=(im_height, im_width),
                                                           class_mode='categorical')
total_train = train_data_gen.n

val_data_gen = val_image_generator.flow_from_directory( directory=val_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                       color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_val = val_data_gen.n

test_data_gen = test_image_generator.flow_from_directory( directory=test_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                         color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_test = test_data_gen.n
# Out:
# Found 39172 images belonging to 3 classes.
# Found 13059 images belonging to 3 classes.
# Found 13059 images belonging to 3 classes.

# %%
# Building the model
covn_base = tf.keras.applications.DenseNet121(weights='imagenet', include_top = False,
                                              input_shape=(im_height,im_width,3))
covn_base.trainable = False
model = tf.keras.Sequential([
        covn_base,
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(units = 32, activation = 'relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(num_classes, activation='softmax',
                              kernel_regularizer='l2'
                             )
    ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Functional)     (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# batch_normalization (BatchNo (None, 7, 7, 1024)        4096
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                32800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 7,074,499
# Trainable params: 34,947
# Non-trainable params: 7,039,552
# _________________________________________________________________

# %%
# Building the model
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Monitor the change of 'val_loss', if the learning rate decays to 1/5 of the original one after four rounds of constant learning
reduce_lr = ReduceLROnPlateau(
                                monitor='val_loss', 
                                factor=0.2, 
                                patience=4, 
                                mode='auto',
                                verbose=VERBOSE
                             )

# Set the model save path and save the optimal model according to val_acc
checkpoint = ModelCheckpoint(
                                filepath=save_path,
                                monitor='val_accuracy', 
                                save_weights_only=True, 
                                save_best_only=True, 
                                mode='auto'
                            )
# Start training
history = model.fit(x=train_data_gen,
                    epochs=epochs,
                    validation_data=val_data_gen,
                    verbose=VERBOSE,
                    callbacks=[checkpoint, reduce_lr])
# Out:
# Epoch 1/50
# 1225/1225 [==============================] - 142s 116ms/step - loss: 0.2317 - accuracy: 0.9280 - val_loss: 0.1226 - val_accuracy: 0.9667
# Epoch 2/50
# 1225/1225 [==============================] - 139s 113ms/step - loss: 0.1422 - accuracy: 0.9564 - val_loss: 0.0936 - val_accuracy: 0.9763
# Epoch 3/50
# 1225/1225 [==============================] - 138s 113ms/step - loss: 0.1250 - accuracy: 0.9626 - val_loss: 0.0836 - val_accuracy: 0.9776
# Epoch 4/50
# 1225/1225 [==============================] - 141s 115ms/step - loss: 0.1054 - accuracy: 0.9674 - val_loss: 0.0704 - val_accuracy: 0.9817
# Epoch 5/50
# 1225/1225 [==============================] - 141s 115ms/step - loss: 0.1026 - accuracy: 0.9677 - val_loss: 0.0684 - val_accuracy: 0.9814
# Epoch 6/50
# 1225/1225 [==============================] - 138s 113ms/step - loss: 0.0953 - accuracy: 0.9703 - val_loss: 0.0604 - val_accuracy: 0.9833
# Epoch 7/50
# 1225/1225 [==============================] - 139s 113ms/step - loss: 0.0892 - accuracy: 0.9722 - val_loss: 0.0547 - val_accuracy: 0.9861
# Epoch 8/50
# 1225/1225 [==============================] - 145s 118ms/step - loss: 0.0848 - accuracy: 0.9739 - val_loss: 0.0541 - val_accuracy: 0.9855
# Epoch 9/50
# 1225/1225 [==============================] - 141s 115ms/step - loss: 0.0825 - accuracy: 0.9748 - val_loss: 0.0531 - val_accuracy: 0.9859
# Epoch 10/50
# 1225/1225 [==============================] - 142s 116ms/step - loss: 0.0786 - accuracy: 0.9760 - val_loss: 0.0488 - val_accuracy: 0.9870
# Epoch 11/50
# 1225/1225 [==============================] - 140s 114ms/step - loss: 0.0756 - accuracy: 0.9776 - val_loss: 0.0527 - val_accuracy: 0.9848
# Epoch 12/50
# 1225/1225 [==============================] - 140s 114ms/step - loss: 0.0707 - accuracy: 0.9789 - val_loss: 0.0463 - val_accuracy: 0.9882
# Epoch 13/50
# 1225/1225 [==============================] - 141s 115ms/step - loss: 0.0704 - accuracy: 0.9787 - val_loss: 0.0468 - val_accuracy: 0.9874
# Epoch 14/50
# 1225/1225 [==============================] - 139s 113ms/step - loss: 0.0705 - accuracy: 0.9792 - val_loss: 0.0457 - val_accuracy: 0.9880
# Epoch 15/50
# 1225/1225 [==============================] - 137s 112ms/step - loss: 0.0689 - accuracy: 0.9796 - val_loss: 0.0441 - val_accuracy: 0.9875
# Epoch 16/50
# 1225/1225 [==============================] - 136s 111ms/step - loss: 0.0687 - accuracy: 0.9797 - val_loss: 0.0443 - val_accuracy: 0.9882
# Epoch 17/50
# 1225/1225 [==============================] - 139s 113ms/step - loss: 0.0643 - accuracy: 0.9809 - val_loss: 0.0420 - val_accuracy: 0.9892
# Epoch 18/50
# 1225/1225 [==============================] - 140s 114ms/step - loss: 0.0648 - accuracy: 0.9803 - val_loss: 0.0427 - val_accuracy: 0.9875
# Epoch 19/50
# 1225/1225 [==============================] - 140s 114ms/step - loss: 0.0636 - accuracy: 0.9804 - val_loss: 0.0396 - val_accuracy: 0.9897
# Epoch 20/50
# 1225/1225 [==============================] - 140s 114ms/step - loss: 0.0606 - accuracy: 0.9819 - val_loss: 0.0390 - val_accuracy: 0.9879
# Epoch 21/50
# 1225/1225 [==============================] - 138s 112ms/step - loss: 0.0600 - accuracy: 0.9818 - val_loss: 0.0395 - val_accuracy: 0.9882
# Epoch 22/50
# 1225/1225 [==============================] - 136s 111ms/step - loss: 0.0604 - accuracy: 0.9814 - val_loss: 0.0389 - val_accuracy: 0.9904
# Epoch 23/50
# 1225/1225 [==============================] - 138s 113ms/step - loss: 0.0606 - accuracy: 0.9818 - val_loss: 0.0380 - val_accuracy: 0.9897
# Epoch 24/50
# 1225/1225 [==============================] - 130s 106ms/step - loss: 0.0580 - accuracy: 0.9820 - val_loss: 0.0357 - val_accuracy: 0.9908
# Epoch 25/50
# 1225/1225 [==============================] - 130s 106ms/step - loss: 0.0590 - accuracy: 0.9820 - val_loss: 0.0367 - val_accuracy: 0.9904
# Epoch 26/50
# 1225/1225 [==============================] - 129s 105ms/step - loss: 0.0571 - accuracy: 0.9828 - val_loss: 0.0368 - val_accuracy: 0.9893
# Epoch 27/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0570 - accuracy: 0.9828 - val_loss: 0.0378 - val_accuracy: 0.9879
# Epoch 28/50
# 1225/1225 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9847
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1225/1225 [==============================] - 134s 109ms/step - loss: 0.0531 - accuracy: 0.9847 - val_loss: 0.0366 - val_accuracy: 0.9886
# Epoch 29/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0490 - accuracy: 0.9855 - val_loss: 0.0341 - val_accuracy: 0.9898
# Epoch 30/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0473 - accuracy: 0.9864 - val_loss: 0.0333 - val_accuracy: 0.9904
# Epoch 31/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0474 - accuracy: 0.9865 - val_loss: 0.0336 - val_accuracy: 0.9904
# Epoch 32/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0460 - accuracy: 0.9867 - val_loss: 0.0329 - val_accuracy: 0.9904
# Epoch 33/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0465 - accuracy: 0.9859 - val_loss: 0.0323 - val_accuracy: 0.9914
# Epoch 34/50
# 1225/1225 [==============================] - 133s 108ms/step - loss: 0.0459 - accuracy: 0.9870 - val_loss: 0.0321 - val_accuracy: 0.9917
# Epoch 35/50
# 1225/1225 [==============================] - 133s 109ms/step - loss: 0.0453 - accuracy: 0.9874 - val_loss: 0.0322 - val_accuracy: 0.9914
# Epoch 36/50
# 1225/1225 [==============================] - 128s 105ms/step - loss: 0.0476 - accuracy: 0.9860 - val_loss: 0.0328 - val_accuracy: 0.9913
# Epoch 37/50
# 1225/1225 [==============================] - 128s 105ms/step - loss: 0.0460 - accuracy: 0.9867 - val_loss: 0.0333 - val_accuracy: 0.9905
# Epoch 38/50
# 1225/1225 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9860
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0462 - accuracy: 0.9860 - val_loss: 0.0321 - val_accuracy: 0.9911
# Epoch 39/50
# 1225/1225 [==============================] - 132s 107ms/step - loss: 0.0456 - accuracy: 0.9869 - val_loss: 0.0319 - val_accuracy: 0.9913
# Epoch 40/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0461 - accuracy: 0.9871 - val_loss: 0.0315 - val_accuracy: 0.9913
# Epoch 41/50
# 1225/1225 [==============================] - 132s 108ms/step - loss: 0.0459 - accuracy: 0.9867 - val_loss: 0.0316 - val_accuracy: 0.9913
# Epoch 42/50
# 1225/1225 [==============================] - 128s 105ms/step - loss: 0.0451 - accuracy: 0.9875 - val_loss: 0.0318 - val_accuracy: 0.9913
# Epoch 43/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0440 - accuracy: 0.9881 - val_loss: 0.0314 - val_accuracy: 0.9914
# Epoch 44/50
# 1225/1225 [==============================] - 132s 108ms/step - loss: 0.0449 - accuracy: 0.9870 - val_loss: 0.0312 - val_accuracy: 0.9917
# Epoch 45/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0456 - accuracy: 0.9867 - val_loss: 0.0316 - val_accuracy: 0.9911
# Epoch 46/50
# 1225/1225 [==============================] - 130s 106ms/step - loss: 0.0460 - accuracy: 0.9864 - val_loss: 0.0314 - val_accuracy: 0.9911
# Epoch 47/50
# 1225/1225 [==============================] - 129s 105ms/step - loss: 0.0448 - accuracy: 0.9881 - val_loss: 0.0311 - val_accuracy: 0.9913
# Epoch 48/50
# 1225/1225 [==============================] - 131s 107ms/step - loss: 0.0433 - accuracy: 0.9873 - val_loss: 0.0315 - val_accuracy: 0.9913
# Epoch 49/50
# 1225/1225 [==============================] - 132s 108ms/step - loss: 0.0459 - accuracy: 0.9869 - val_loss: 0.0311 - val_accuracy: 0.9913
# Epoch 50/50
# 1225/1225 [==============================] - 130s 106ms/step - loss: 0.0450 - accuracy: 0.9870 - val_loss: 0.0316 - val_accuracy: 0.9913

# %%
# Plotting model accuracy and loss variation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Load the best model in training
try:
    model.load_weights("./save_weights/224/des121/des121_224-22-0.99.h5")
    print("Loading model successfully")
except :    
    print("Failed to load model")
# Out:
# Loading model successfully

# %%
val_loss, val_acc = model.evaluate(val_data_gen)

print('\nVal accuracy:', val_acc)
print('\nVal loss:', val_loss)
# Out:
# 409/409 [==============================] - 35s 85ms/step - loss: 0.0389 - accuracy: 0.9904
#
# Val accuracy: 0.9904280304908752
#
# Val loss: 0.03894712030887604

# %%
test_loss, test_acc = model.evaluate(test_data_gen)

print('\nTest accuracy:', test_acc)
print('\nTest loss:', test_loss)
# Out:
# 409/409 [==============================] - 33s 80ms/step - loss: 0.0408 - accuracy: 0.9900
#
# Test accuracy: 0.9899685978889465
#
# Test loss: 0.04076533019542694

# %%
def plot_confusion_matrix(cm):
    print(cm)
    accuracy = np.trace(cm) / float(np.sum(cm))
    precision = (cm[0][0]/cm.sum(axis=0)[0] + cm[1][1]/cm.sum(axis=0)[1] + cm[2][2]/cm.sum(axis=0)[2])/3
    recall = (cm[0][0]/cm.sum(axis=1)[0] + cm[1][1]/cm.sum(axis=1)[1] + cm[2][2]/cm.sum(axis=1)[2])/3
    f1 = 2*precision*recall/(precision + recall)
    print('accuracy',accuracy)
    print('precision',precision)
    print('recall',recall)
    print('f1',f1)

# %%
# Predict the overall accuracy of the validation set data
Y_pred = model.predict(val_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = val_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[1906   14    0]
#  [  17 4646   21]
#  [   0   73 6382]]
# accuracy 0.9904280572785052
# precision 0.9898327858612724
# recall 0.9910955154746315
# f1 0.9904637482086415

# %%
# Predict the overall accuracy of the test set data
Y_pred = model.predict(test_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = test_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[1898   22    0]
#  [  26 4632   26]
#  [   3   54 6398]]
# accuracy 0.9899686040278735
# precision 0.9882535474204861
# recall 0.989536560020988
# f1 0.9888946375690618

# %%
# Record the predicted classification and predicted probability in the table
# import csv
# from keras.utils import to_categorical

# Y_test = to_categorical(test_data_gen.labels)
# Y_tes = Y_test.ravel()
# Y_pre = Y_pred.ravel()
# num = len(Y_tes)

# with open(save_json,'w',newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     for i in range(num):
#         writer.writerow([Y_tes[i], Y_pre[i]])

# %%
# Statistical prediction of misclassified images
import csv

misclass = []
# Save as csv file
with open('pred.csv', 'w', newline="") as csvfile:
    fieldnames = ['i', 'file_name', 'pred_label', 'ground_label']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)    
    writer.writeheader()
    num = len(test_data_gen.filenames)

    for i in range(num):
        file_name = test_data_gen.filenames[i]
        pred = Y_pred_classes[i]+1
        ground = int(file_name[:1])
        if pred != ground:
            str = {'i': i, 
                   'file_name': file_name, 
                   'pred_label': pred, 
                   'ground_label': ground}
            writer.writerow(str)
            line=[i,file_name,pred,ground,Y_pred[i]]
            misclass.append(line)
# print(misclass)

# %%
fig = plt.figure(figsize=(26,26))
a=1
img_scale = (600, 600)
num = min(len(misclass),12)

for i in range(num):
    img = Image.open(os.path.join(image_path, 'test' , misclass[i][1]))
    img = img.resize(img_scale)
    img = img.convert("RGB")
    plt.subplot(4,3,a)
    plt.axis('off')
    a+=1
    
    plt.title(['pre:',misclass[i][2],  # Prediction classification
               'gt:', misclass[i][3],  # Actual classification
               'pro:', ''.join( '%.5s ' %a for a in misclass[i][4] )], fontsize=20) # Probability
    plt.imshow(img)
plt.show()
