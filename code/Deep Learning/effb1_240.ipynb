# %%
# Importing the appropriate libraries
import keras.backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import numpy as np
import itertools
import os
import keras

# %%
# Initial settings
im_height = 240 
im_width = 240
batch_size = 32
epochs = 50
num_classes = 3
labels = ['1','2','3']
save_path = './save_weights/effb1_240-{epoch:02d}-{val_accuracy:.2f}.h5'
save_json = './csv/effb1_240.csv'

image_path = 'G:/dataset/seedling_classification_300/'
train_dir = image_path + "train"
val_dir = image_path + "val"
test_dir = image_path + "test"

# %%
# Data pre-processing
train_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
#     horizontal_flip=True,
#     vertical_flip=True,
)
val_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)
test_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
# Generate dataset
train_data_gen = train_image_generator.flow_from_directory(directory=train_dir,
                                                           batch_size=batch_size,
                                                           shuffle=True,
                                                           color_mode="rgb",
                                                           target_size=(im_height, im_width),
                                                           class_mode='categorical')
total_train = train_data_gen.n

val_data_gen = val_image_generator.flow_from_directory( directory=val_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                       color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_val = val_data_gen.n

test_data_gen = test_image_generator.flow_from_directory( directory=test_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                         color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_test = test_data_gen.n
# Out:
# Found 10896 images belonging to 3 classes.
# Found 3633 images belonging to 3 classes.
# Found 3634 images belonging to 3 classes.

# %%
# Building the model
covn_base = tf.keras.applications.EfficientNetB1(weights='imagenet', include_top = False,
                                              input_shape=(im_height,im_width,3))
covn_base.trainable = False
model = tf.keras.Sequential([
        covn_base,
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(units = 32, activation = 'relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(num_classes, activation='softmax',
                              kernel_regularizer='l2'
                             )
    ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb1 (Functional)  (None, 8, 8, 1280)        6575239
# _________________________________________________________________
# batch_normalization (BatchNo (None, 8, 8, 1280)        5120
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 1280)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                40992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 6,621,450
# Trainable params: 43,651
# Non-trainable params: 6,577,799
# _________________________________________________________________

# %%
# Building the model
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Monitor the change of 'val_loss', if the learning rate decays to 1/5 of the original one after four rounds of constant learning
reduce_lr = ReduceLROnPlateau(
                                monitor='val_loss', 
                                factor=0.2, 
                                patience=4, 
                                mode='auto',
                                verbose=VERBOSE
                             )

# Set the model save path and save the optimal model according to val_acc
checkpoint = ModelCheckpoint(
                                filepath=save_path,
                                monitor='val_accuracy', 
                                save_weights_only=True, 
                                save_best_only=True, 
                                mode='auto'
                            )
# Start training
history = model.fit(x=train_data_gen,
                    epochs=epochs,
                    validation_data=val_data_gen,
                    verbose=VERBOSE,
                    callbacks=[checkpoint, reduce_lr])
# Out:
# Epoch 1/50
# 340/340 [==============================] - 47s 138ms/step - loss: 0.3397 - accuracy: 0.8897 - val_loss: 0.2133 - val_accuracy: 0.9347
# Epoch 2/50
# 340/340 [==============================] - 47s 139ms/step - loss: 0.2239 - accuracy: 0.9286 - val_loss: 0.1553 - val_accuracy: 0.9582
# Epoch 3/50
# 340/340 [==============================] - 47s 139ms/step - loss: 0.1923 - accuracy: 0.9388 - val_loss: 0.1397 - val_accuracy: 0.9574
# Epoch 4/50
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1827 - accuracy: 0.9426 - val_loss: 0.1437 - val_accuracy: 0.9563
# Epoch 5/50
# 340/340 [==============================] - 47s 138ms/step - loss: 0.1699 - accuracy: 0.9436 - val_loss: 0.1343 - val_accuracy: 0.9591
# Epoch 6/50
# 340/340 [==============================] - 47s 138ms/step - loss: 0.1624 - accuracy: 0.9474 - val_loss: 0.1125 - val_accuracy: 0.9671
# Epoch 7/50
# 340/340 [==============================] - 47s 139ms/step - loss: 0.1533 - accuracy: 0.9494 - val_loss: 0.1094 - val_accuracy: 0.9654
# Epoch 8/50
# 340/340 [==============================] - 48s 140ms/step - loss: 0.1465 - accuracy: 0.9522 - val_loss: 0.1021 - val_accuracy: 0.9676
# Epoch 9/50
# 340/340 [==============================] - 47s 138ms/step - loss: 0.1391 - accuracy: 0.9540 - val_loss: 0.1066 - val_accuracy: 0.9671
# Epoch 10/50
# 340/340 [==============================] - 46s 137ms/step - loss: 0.1338 - accuracy: 0.9554 - val_loss: 0.1046 - val_accuracy: 0.9674
# Epoch 11/50
# 340/340 [==============================] - 47s 139ms/step - loss: 0.1370 - accuracy: 0.9539 - val_loss: 0.0984 - val_accuracy: 0.9690
# Epoch 12/50
# 340/340 [==============================] - 46s 136ms/step - loss: 0.
50
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1096 - accuracy: 0.9657 - val_loss: 0.0860 - val_accuracy: 0.9723
# Epoch 34/50
# 340/340 [==============================] - 47s 137ms/step - loss: 0.1052 - accuracy: 0.9640 - val_loss: 0.0861 - val_accuracy: 0.9726
# Epoch 35/50
# 340/340 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9669
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1038 - accuracy: 0.9669 - val_loss: 0.0861 - val_accuracy: 0.9723
# Epoch 36/50
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1055 - accuracy: 0.9661 - val_loss: 0.0864 - val_accuracy: 0.9723
# Epoch 37/50
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1090 - accuracy: 0.9641 - val_loss: 0.0861 - val_accuracy: 0.9721
# Epoch 38/50
# 340/340 [==============================] - 46s 134ms/step - loss: 0.1060 - accuracy: 0.9657 - val_loss: 0.0857 - val_accuracy: 0.9723
# Epoch 39/50
# 340/340 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9650 ETA: 1s - l
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 340/340 [==============================] - 45s 134ms/step - loss: 0.1080 - accuracy: 0.9650 - val_loss: 0.0880 - val_accuracy: 0.9721
# Epoch 40/50
# 340/340 [==============================] - 47s 139ms/step - loss: 0.1037 - accuracy: 0.9673 - val_loss: 0.0854 - val_accuracy: 0.9729
# Epoch 41/50
# 340/340 [==============================] - 47s 139ms/step - loss: 0.1077 - accuracy: 0.9645 - val_loss: 0.0865 - val_accuracy: 0.9723
# Epoch 42/50
# 340/340 [==============================] - 47s 138ms/step - loss: 0.1094 - accuracy: 0.9634 - val_loss: 0.0862 - val_accuracy: 0.9723
# Epoch 43/50
# 340/340 [==============================] - 47s 137ms/step - loss: 0.1111 - accuracy: 0.9636 - val_loss: 0.0843 - val_accuracy: 0.9729
# Epoch 44/50
# 340/340 [==============================] - 47s 138ms/step - loss: 0.1061 - accuracy: 0.9665 - val_loss: 0.0858 - val_accuracy: 0.9723
# Epoch 45/50
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1102 - accuracy: 0.9652 - val_loss: 0.0865 - val_accuracy: 0.9721
# Epoch 46/50
# 340/340 [==============================] - 46s 134ms/step - loss: 0.1073 - accuracy: 0.9640 - val_loss: 0.0864 - val_accuracy: 0.9723
# Epoch 47/50
# 340/340 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9666
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1048 - accuracy: 0.9666 - val_loss: 0.0855 - val_accuracy: 0.9726
# Epoch 48/50
# 340/340 [==============================] - 46s 136ms/step - loss: 0.1086 - accuracy: 0.9628 - val_loss: 0.0851 - val_accuracy: 0.9732
# Epoch 49/50
# 340/340 [==============================] - 46s 135ms/step - loss: 0.1077 - accuracy: 0.9658 - val_loss: 0.0855 - val_accuracy: 0.9729
# Epoch 50/50
# 340/340 [==============================] - 47s 138ms/step - loss: 0.1044 - accuracy: 0.9677 - val_loss: 0.0856 - val_accuracy: 0.9721

# %%
# Plotting model accuracy and loss variation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Load the best model in training
try:
    model.load_weights("./save_weights/240/effb1_240-48-0.97.h5")
    print("Loading model successfully")
except :    
    print("Failed to load model")
# Out:
# Loading model successfully

# %%
test_loss, test_acc = model.evaluate(val_data_gen)

print('\nTest accuracy:', test_acc)
print('\nTest loss:', test_loss)
# Out:
# 114/114 [==============================] - 12s 104ms/step - loss: 0.0853 - accuracy: 0.9730
#
# Test accuracy: 0.9730250239372253
#
# Test loss: 0.08526799827814102

# %%
test_loss, test_acc = model.evaluate(test_data_gen)

print('\nTest accuracy:', test_acc)
print('\nTest loss:', test_loss)
# Out:
# 114/114 [==============================] - 12s 105ms/step - loss: 0.0816 - accuracy: 0.9752
#
# Test accuracy: 0.9752339124679565
#
# Test loss: 0.08158856630325317

# %%
def plot_confusion_matrix(cm):
    print(cm)
    accuracy = np.trace(cm) / float(np.sum(cm))
    precision = (cm[0][0]/cm.sum(axis=0)[0] + cm[1][1]/cm.sum(axis=0)[1] + cm[2][2]/cm.sum(axis=0)[2])/3
    recall = (cm[0][0]/cm.sum(axis=1)[0] + cm[1][1]/cm.sum(axis=1)[1] + cm[2][2]/cm.sum(axis=1)[2])/3
    f1 = 2*precision*recall/(precision + recall)
    print('accuracy',accuracy)
    print('precision',precision)
    print('recall',recall)
    print('f1',f1)

# %%
# Predict the overall accuracy of the validation set data
Y_pred = model.predict(val_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = val_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[1076    2    1]
#  [  14 1311   62]
#  [   0   19 1148]]
# accuracy 0.9730250481695568
# precision 0.9731223587165679
# recall 0.975381354906852
# f1 0.9742505473290151

# %%
# Predict the overall accuracy of the test set data
Y_pred = model.predict(test_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = test_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[1075    4    0]
#  [  11 1315   62]
#  [   0   13 1154]]
# accuracy 0.9752339020363237
# precision 0.9753738272293812
# recall 0.9775198431472104
# f1 0.9764456560702542

# %%
# Record the predicted classification and predicted probability in the table
# import csv
# from keras.utils import to_categorical

# Y_test = to_categorical(test_data_gen.labels)
# Y_tes = Y_test.ravel()
# Y_pre = Y_pred.ravel()
# num = len(Y_tes)

# with open(save_json,'w',newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     for i in range(num):
#         writer.writerow([Y_tes[i], Y_pre[i]])

# %%
# Statistical prediction of misclassified images
import csv

misclass = []
# Save as csv file
with open('pred.csv', 'w', newline="") as csvfile:
    fieldnames = ['i', 'file_name', 'pred_label', 'ground_label']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)    
    writer.writeheader()
    num = len(test_data_gen.filenames)

    for i in range(num):
        file_name = test_data_gen.filenames[i]
        pred = Y_pred_classes[i]+1
        ground = int(file_name[:1])
        if pred != ground:
            str = {'i': i, 
                   'file_name': file_name, 
                   'pred_label': pred, 
                   'ground_label': ground}
            writer.writerow(str)
            line=[i,file_name,pred,ground,Y_pred[i]]
            misclass.append(line)
# print(misclass)

# %%
fig = plt.figure(figsize=(26,26))
a=1
img_scale = (600, 600)
num = min(len(misclass),12)

for i in range(num):
    img = Image.open(os.path.join(image_path, 'test' , misclass[i][1]))
    img = img.resize(img_scale)
    img = img.convert("RGB")
    plt.subplot(4,3,a)
    plt.axis('off')
    a+=1
    
    plt.title(['pre:',misclass[i][2],  # Prediction classification
               'gt:', misclass[i][3],  # Actual classification
               'pro:', ''.join( '%.5s ' %a for a in misclass[i][4] )], fontsize=20) # Probability
    plt.imshow(img)
plt.show()
