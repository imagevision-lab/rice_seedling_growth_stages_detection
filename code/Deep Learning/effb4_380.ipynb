# %%
# Importing the appropriate libraries
import keras.backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import numpy as np
import itertools
import os
import keras

# %%
# Initial settings
im_height = 380 
im_width = 380
batch_size = 8
epochs = 50
num_classes = 3
labels = ['1','2','3']
save_path = './save_weights/380/effb4_380-{epoch:02d}-{val_accuracy:.2f}.h5'
save_json = './csv/effb4_380.csv'

image_path = 'G:/dataset/seedling_classification_400/'
VERBOSE = 1
train_dir = image_path + "train"
val_dir = image_path + "val"
test_dir = image_path + "test"

# %%
# Data pre-processing
train_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
#     horizontal_flip=True,
#     vertical_flip=True,
)
val_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)
test_image_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
# Generate dataset
train_data_gen = train_image_generator.flow_from_directory(directory=train_dir,
                                                           batch_size=batch_size,
                                                           shuffle=True,
                                                           color_mode="rgb",
                                                           target_size=(im_height, im_width),
                                                           class_mode='categorical')
total_train = train_data_gen.n

val_data_gen = val_image_generator.flow_from_directory( directory=val_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                       color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_val = val_data_gen.n

test_data_gen = test_image_generator.flow_from_directory( directory=test_dir,
                                                          batch_size=batch_size,
                                                          shuffle=False,
                                                         color_mode="rgb",
                                                          target_size=(im_height, im_width),
                                                          class_mode='categorical')
total_test = test_data_gen.n
# Out:
# Found 7258 images belonging to 3 classes.
# Found 2420 images belonging to 3 classes.
# Found 2420 images belonging to 3 classes.

# %%
# Building the model
covn_base = tf.keras.applications.EfficientNetB4(weights='imagenet', include_top = False,
                                              input_shape=(im_height,im_width,3))
covn_base.trainable = False
model = tf.keras.Sequential([
        covn_base,
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(units = 32, activation = 'relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(num_classes, activation='softmax',
                              kernel_regularizer='l2'
                             )
    ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb4 (Functional)  (None, 12, 12, 1792)      17673823
# _________________________________________________________________
# batch_normalization (BatchNo (None, 12, 12, 1792)      7168
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 1792)      0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1792)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                57376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 17,738,466
# Trainable params: 61,059
# Non-trainable params: 17,677,407
# _________________________________________________________________

# %%
# Building the model
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Monitor the change of 'val_loss', if the learning rate decays to 1/5 of the original one after four rounds of constant learning
reduce_lr = ReduceLROnPlateau(
                                monitor='val_loss', 
                                factor=0.2, 
                                patience=4, 
                                mode='auto',
                                verbose=VERBOSE
                             )

# Set the model save path and save the optimal model according to val_acc
checkpoint = ModelCheckpoint(
                                filepath=save_path,
                                monitor='val_accuracy', 
                                save_weights_only=True, 
                                save_best_only=True, 
                                mode='auto'
                            )
# Start training
history = model.fit(x=train_data_gen,
                    epochs=epochs,
                    validation_data=val_data_gen,
                    verbose=VERBOSE,
                    callbacks=[checkpoint, reduce_lr])
# Out:
# Epoch 1/50
# 908/908 [==============================] - 77s 85ms/step - loss: 0.2903 - accuracy: 0.9064 - val_loss: 0.1106 - val_accuracy: 0.9702
# Epoch 2/50
# 908/908 [==============================] - 74s 82ms/step - loss: 0.1956 - accuracy: 0.9381 - val_loss: 0.0778 - val_accuracy: 0.9810
# Epoch 3/50
# 908/908 [==============================] - 75s 82ms/step - loss: 0.1708 - accuracy: 0.9445 - val_loss: 0.0667 - val_accuracy: 0.9855
# Epoch 4/50
# 908/908 [==============================] - 75s 82ms/step - loss: 0.1515 - accuracy: 0.9504 - val_loss: 0.0625 - val_accuracy: 0.9855
# Epoch 5/50
# 908/908 [==============================] - 75s 82ms/step - loss: 0.1543 - accuracy: 0.9505 - val_loss: 0.0789 - val_accuracy: 0.9822
# Epoch 6/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1410 - accuracy: 0.9521 - val_loss: 0.0575 - val_accuracy: 0.9868
# Epoch 7/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1364 - accuracy: 0.9549 - val_loss: 0.0458 - val_accuracy: 0.9893
# Epoch 8/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1248 - accuracy: 0.9581 - val_loss: 0.0484 - val_accuracy: 0.9876
# Epoch 9/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1222 - accuracy: 0.9610 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 10/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1173 - accuracy: 0.9599 - val_loss: 0.0389 - val_accuracy: 0.9905
# Epoch 11/50
# 908/908 [==============================] - 76s 83ms/step - loss: 0.1154 - accuracy: 0.9631 - val_loss: 0.0569 - val_accuracy: 0.9855
# Epoch 12/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1104 - accuracy: 0.9625 - val_loss: 0.0420 - val_accuracy: 0.9876
# Epoch 13/50
# 908/908 [==============================] - 76s 83ms/step - loss: 0.1070 - accuracy: 0.9657 - val_loss: 0.0312 - val_accuracy: 0.9946
# Epoch 14/50
# 908/908 [==============================] - 75s 82ms/step - loss: 0.1025 - accuracy: 0.9645 - val_loss: 0.0375 - val_accuracy: 0.9888
# Epoch 15/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1082 - accuracy: 0.9640 - val_loss: 0.0379 - val_accuracy: 0.9893
# Epoch 16/50
# 908/908 [==============================] - 75s 82ms/step - loss: 0.1031 - accuracy: 0.9689 - val_loss: 0.0354 - val_accuracy: 0.9909
# Epoch 17/50
# 908/908 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9676
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 908/908 [==============================] - 75s 83ms/step - loss: 0.1024 - accuracy: 0.9676 - val_loss: 0.0619 - val_accuracy: 0.9818
# Epoch 18/50
# 908/908 [==============================] - 75s 83ms/step - loss: 0.
# 908/908 [==============================] - 73s 81ms/step - loss: 0.0759 - accuracy: 0.9751 - val_loss: 0.0297 - val_accuracy: 0.9938
# Epoch 49/50
# 908/908 [==============================] - 73s 80ms/step - loss: 0.0828 - accuracy: 0.9751 - val_loss: 0.0291 - val_accuracy: 0.9942
# Epoch 50/50
# 908/908 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9756
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 908/908 [==============================] - 73s 81ms/step - loss: 0.0799 - accuracy: 0.9756 - val_loss: 0.0287 - val_accuracy: 0.9942

# %%
# Plotting model accuracy and loss variation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Load the best model in training
try:
    model.load_weights("./save_weights/380/effb4_380-17-0.99.h5")
    print("Loading model successfully")
except :    
    print("Failed to load model")
# Out:
# Loading model successfully

# %%
test_loss, test_acc = model.evaluate(val_data_gen)

print('\nTest accuracy:', test_acc)
print('\nTest loss:', test_loss)
# Out:
# 303/303 [==============================] - 19s 61ms/step - loss: 0.0316 - accuracy: 0.9930
#
# Test accuracy: 0.9929752349853516
#
# Test loss: 0.03162940964102745

# %%
test_loss, test_acc = model.evaluate(test_data_gen)

print('\nTest accuracy:', test_acc)
print('\nTest loss:', test_loss)
# Out:
# 303/303 [==============================] - 18s 60ms/step - loss: 0.0397 - accuracy: 0.9921
#
# Test accuracy: 0.992148756980896
#
# Test loss: 0.03973783925175667

# %%
def plot_confusion_matrix(cm):
    print(cm)
    accuracy = np.trace(cm) / float(np.sum(cm))
    precision = (cm[0][0]/cm.sum(axis=0)[0] + cm[1][1]/cm.sum(axis=0)[1] + cm[2][2]/cm.sum(axis=0)[2])/3
    recall = (cm[0][0]/cm.sum(axis=1)[0] + cm[1][1]/cm.sum(axis=1)[1] + cm[2][2]/cm.sum(axis=1)[2])/3
    f1 = 2*precision*recall/(precision + recall)
    print('accuracy',accuracy)
    print('precision',precision)
    print('recall',recall)
    print('f1',f1)

# %%
# Predict the overall accuracy of the validation set data
Y_pred = model.predict(val_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = val_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[ 563    0    0]
#  [   4  693   12]
#  [   0    1 1147]]
# accuracy 0.9929752066115702
# precision 0.9937168836176365
# recall 0.9921873080306463
# f1 0.9929515067721907

# %%
# Predict the overall accuracy of the test set data
Y_pred = model.predict(test_data_gen, batch_size)
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Draw confusion matrix
confusion_mtx = confusion_matrix(y_true = test_data_gen.classes,y_pred = Y_pred_classes)
plot_confusion_matrix(confusion_mtx)
# Out:
# [[ 561    2    0]
#  [   4  697    8]
#  [   3    2 1143]]
# accuracy 0.9921487603305785
# precision 0.9916731481328417
# recall 0.9917223182026862
# f1 0.99169773255828

# %%
# Record the predicted classification and predicted probability in the table
# import csv
# from keras.utils import to_categorical

# Y_test = to_categorical(test_data_gen.labels)
# Y_tes = Y_test.ravel()
# Y_pre = Y_pred.ravel()
# num = len(Y_tes)

# with open(save_json,'w',newline='') as csvfile:
#     writer = csv.writer(csvfile)
#     for i in range(num):
#         writer.writerow([Y_tes[i], Y_pre[i]])

# %%
# Statistical prediction of misclassified images
import csv

misclass = []
# Save as csv file
with open('pred.csv', 'w', newline="") as csvfile:
    fieldnames = ['i', 'file_name', 'pred_label', 'ground_label']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)    
    writer.writeheader()
    num = len(test_data_gen.filenames)

    for i in range(num):
        file_name = test_data_gen.filenames[i]
        pred = Y_pred_classes[i]+1
        ground = int(file_name[:1])
        if pred != ground:
            str = {'i': i, 
                   'file_name': file_name, 
                   'pred_label': pred, 
                   'ground_label': ground}
            writer.writerow(str)
            line=[i,file_name,pred,ground,Y_pred[i]]
            misclass.append(line)
# print(misclass)

# %%
fig = plt.figure(figsize=(26,26))
a=1
img_scale = (600, 600)
num = min(len(misclass),12)

for i in range(num):
    img = Image.open(os.path.join(image_path, 'test' , misclass[i][1]))
    img = img.resize(img_scale)
    img = img.convert("RGB")
    plt.subplot(4,3,a)
    plt.axis('off')
    a+=1
    
    plt.title(['pre:',misclass[i][2],  # Prediction classification
               'gt:', misclass[i][3],  # Actual classification
               'pro:', ''.join( '%.5s ' %a for a in misclass[i][4] )], fontsize=20) # Probability
    plt.imshow(img)
plt.show()
